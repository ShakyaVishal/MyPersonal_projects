# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv")
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(x = data['Critic_Score'], y = data['Global_Sales'])
plt.ylabel('Global_Sales', fontsize=13)
plt.xlabel('Critic_Score', fontsize=13)
plt.show()

# %%
data = data.drop(data[(data['Critic_Score']>60) & (data['Global_Sales']>60)].index)

# %%
fig, ax = plt.subplots()
ax.scatter(x = data['Critic_Score'], y = data['Global_Sales'])
plt.ylabel('Global_Sales', fontsize=13)
plt.xlabel('Critic_Score', fontsize=13)
plt.show()

# %%
#plt.figure(figuresize=(10,5)
           
#sns.heatmap(data.corr())

# %%
data.info()

data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16718 entries, 1 to 16718
# Data columns (total 16 columns):
# Name               16716 non-null object
# Platform           16718 non-null object
# Year_of_Release    16449 non-null float64
# Genre              16716 non-null object
# Publisher          16664 non-null object
# NA_Sales           16718 non-null float64
# EU_Sales           16718 non-null float64
# JP_Sales           16718 non-null float64
# Other_Sales        16718 non-null float64
# Global_Sales       16718 non-null float64
# Critic_Score       8136 non-null float64
# Critic_Count       8136 non-null float64
# User_Score         10014 non-null object
# User_Count         7589 non-null float64
# Developer          10095 non-null object
# Rating             9949 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.2+ MB
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# ...

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %%
data.describe()
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales  \
# count      6824.000000  6824.000000  6824.000000  6824.000000  6824.000000
# mean       2007.436987     0.388480     0.231880     0.063615     0.081451
# std           4.211521     0.830649     0.592917     0.284069     0.250157
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.060000     0.020000     0.000000     0.010000
# 50%        2007.000000     0.150000     0.060000     0.000000     0.020000
# 75%        2011.000000     0.390000     0.210000     0.010000     0.070000
# max        2016.000000    15.680000    12.760000     6.500000    10.570000
#
#        Global_Sales  Critic_Score  Critic_Count    User_Count
# count   6824.000000   6824.000000   6824.000000   6824.000000
# mean       0.765610     70.271249     28.927902    174.700762
# std        1.695872     13.869415     19.223717    587.468878
# ...

# %%
data.isna().sum()
# Out:
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %%
#sns.heatmap(data, vmin=0,vmax=1)

data.head(3)
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 6          65.0        8.5       431.0  Nintendo      E

# %%
data.Publisher.value_counts()
# Out:
# Electronic Arts                           944
# Ubisoft                                   496
# Activision                                492
# Sony Computer Entertainment               316
# THQ                                       307
# Nintendo                                  290
# Sega                                      284
# Take-Two Interactive                      273
# Konami Digital Entertainment              244
# Namco Bandai Games                        239
# Capcom                                    197
# Atari                                     176
# Microsoft Game Studios                    141
# Tecmo Koei                                137
# Square Enix                               134
# Warner Bros. Interactive Entertainment    130
# Eidos Interactive                         123
# Vivendi Games                             113
# Codemasters                               111
# Midway Games                              103
# ...

# %%
# Set the style of the visualization
sns.set(style="darkgrid")

# Create a covariance matrix
corr = data.corr()

# Generate a mask the size of our covariance matrix
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize = (7,5))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
sns.heatmap(corr)

# %%
# Plotting histograms of the continuous variables
data.hist(figsize=(10,10));

# %%
print(data.columns)
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.head(2)
# Out:
#                 Name Platform  Year_of_Release   Genre Publisher  NA_Sales  \
# 2     Mario Kart Wii      Wii           2008.0  Racing  Nintendo     15.68
# 3  Wii Sports Resort      Wii           2009.0  Sports  Nintendo     15.61
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 2     12.76      3.79         3.29         35.52          82.0          73.0
# 3     10.93      3.28         2.95         32.77          80.0          73.0
#
#   User_Score  User_Count Developer Rating
# 2        8.3       709.0  Nintendo      E
# 3          8       192.0  Nintendo      E

# %%
Le=LabelEncoder()

data.iloc[:,0]=Le.fit_transform(data.iloc[:,0])   ##Name
data.iloc[:,3]=Le.fit_transform(data.iloc[:,3])   ##Genre
data.iloc[:,4]=Le.fit_transform(data.iloc[:,4])   ##Publisher
data.iloc[:,14]=Le.fit_transform(data.iloc[:,14])   ##Developer
data.iloc[:,15]=Le.fit_transform(data.iloc[:,15])  ## Rating



#data=Le.fit_transform(data)
data=data.apply(Le.fit_transform)

# %%
data.tail(4)
# Out:
#        Name  Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 16677  2297         3               10      2        146         1         0
# 16696  2194         5               22      0        123         0         1
# 16700   407         5               19      8         53         1         0
# 16706  3094         5               19     11        240         0         1
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 16677         0            0             0            63             9
# 16696         0            0             0            62            17
# 16700         0            0             0            43             9
# 16706         0            0             0            42             9
#
#        User_Score  User_Count  Developer  Rating
# 16677          80           5        260       4
# 16696          68         369        617       4
# 16700          50          39         99       6
# ...

# %%
y=data.iloc[:,9]
y.head(2)
# Out:
# 2    534
# 3    533
# Name: Global_Sales, dtype: int64

# %%
#x=data.iloc[:,3]
x=data.loc[:, data.columns != 'Global_Sales']

# %%
x.head(2)
# Out:
#    Name  Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 2  2087        12               16      6        160       349       271
# 3  4216        12               17     10        160       348       270
#
#    JP_Sales  Other_Sales  Critic_Score  Critic_Count  User_Score  User_Count  \
# 2       147          139            64            70          75         522
# 3       143          138            62            70          72         187
#
#    Developer  Rating
# 2        771       1
# 3        771       1

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(x,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers

#plot graph of feature importances for better visualization

feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.0703454  0.0534349  0.0629843  0.05416692 0.06003075 0.10845058
#  0.09091148 0.04032493 0.07296484 0.06835941 0.07017208 0.06900516
#  0.06986556 0.06580513 0.04317857]

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# ## 1. Linear regression

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.30,random_state=45 )

# %%
print('train_x=',train_x.shape)
print('train_y=',train_y.shape)
print('test_x=',test_x.shape)
print('test_y=',test_y.shape)
# Out:
# train_x= (4776, 15)
# train_y= (4776,)
# test_x= (2048, 15)
# test_y= (2048,)

# %%
lr=LinearRegression()
lr.fit(train_x,train_y)
print("Accuracy_score=",lr.score(train_x,train_y))
# Out:
# Accuracy_score= 0.971730124942294

# %%
lr.predict(test_x)
# Out:
# array([157.09136481,  29.78109366,  21.72967194, ..., 548.14637088,
#         23.49247429, 359.80466705])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()
rfr.fit(train_x,train_y)
pred=rfr.predict(test_x)
print("Accuracy_score=",rfr.score(train_x,train_y))
# Out:
# Accuracy_score= 0.9983639794855427

# %%
pred
# Out:
# array([168. ,  22.5,  20. , ..., 493.9,  21. , 371.5])
